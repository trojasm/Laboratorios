# %% [markdown]
# **Laboratorio 3**

# %% [markdown]
# Certificado no 1

# %% [markdown]
# ![IBM PY0101EN Certificate _ Cognitive Class.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Certificado no 2**

# %% [markdown]
# ![IBM DA0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Certificado no 3

# %% [markdown]
# ![IBM DV0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)
